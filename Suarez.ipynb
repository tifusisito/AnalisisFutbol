# %% [markdown]
# Dataset provided by:
#
# - Pappalardo et al., (2019) A public data set of spatio-temporal match events in soccer competitions, Nature Scientific Data 6:236, https://www.nature.com/articles/s41597-019-0247-7
#
# - Pappalardo et al. (2019) PlayeRank: Data-driven Performance Evaluation and Player Ranking in Soccer via a Machine Learning Approach. ACM Transactions on Intellingent Systems and Technologies (TIST) 10, 5, Article 59 (September 2019), 27 pages. DOI: https://doi.org/10.1145/3343172
#
# https://www.nature.com/articles/s41597-019-0247-7#Tab1

# %%
import numpy as np
import pandas as pd
import matplotlib.style as sty
import matplotlib.pyplot as plt
from matplotlib.patches import Arc
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from matplotlib.collections import LineCollection
from sklearn.linear_model import LinearRegression
from sklearn.isotonic import IsotonicRegression

# %%
teams = pd.read_json(r'D:\JGB_Files\DSKTP_2020_05\Football\teams.json')
teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 6 columns):
# city            142 non-null object
# name            142 non-null object
# wyId            142 non-null int64
# officialName    142 non-null object
# area            142 non-null object
# type            142 non-null object
# dtypes: int64(1), object(5)
# memory usage: 6.8+ KB

# %%
print(teams[teams.officialName == 'Uruguay'])
IdUruguay = 15670
# Out:
#            city     name   wyId officialName  \
# 119  Montevideo  Uruguay  15670      Uruguay
#
#                                                   area      type
# 119  {'name': 'Uruguay', 'id': 858, 'alpha3code': '...  national

# %%
players = pd.read_json(r'D:\JGB_Files\DSKTP_2020_05\Football\players.json')
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3603 entries, 0 to 3602
# Data columns (total 14 columns):
# passportArea             3603 non-null object
# weight                   3603 non-null int64
# firstName                3603 non-null object
# middleName               3603 non-null object
# lastName                 3603 non-null object
# currentTeamId            3512 non-null object
# birthDate                3603 non-null object
# height                   3603 non-null int64
# role                     3603 non-null object
# birthArea                3603 non-null object
# wyId                     3603 non-null int64
# foot                     3603 non-null object
# shortName                3603 non-null object
# currentNationalTeamId    3603 non-null object
# dtypes: int64(3), object(11)
# memory usage: 394.2+ KB

# %%
playersNames = players.filter(items=['wyId', 'shortName'])
playersNames
# Out:
#         wyId        shortName
# 0      32777         H. Tekin
# 1     393228          M. Sarr
# 2     393230      O. Mandanda
# 3      32793       A. N'Diaye
# 4     393247   I. Konat\u00e9
# ...      ...              ...
# 3598  120839  A. Ma\u00e2loul
# 3599  114736   C. C\u00e1ceda
# 3600  114908        M. Araujo
# 3601  285583     A. Tagnaouti
# 3602  361536         R. Avila
#
# [3603 rows x 2 columns]

# %%
eventsWC = pd.read_json(r'D:\JGB_Files\DSKTP_2020_05\Football\events_World_Cup.json')
eventsWC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101759 entries, 0 to 101758
# Data columns (total 12 columns):
# eventId         101759 non-null int64
# subEventName    101759 non-null object
# tags            101759 non-null object
# playerId        101759 non-null int64
# positions       101759 non-null object
# matchId         101759 non-null int64
# eventName       101759 non-null object
# teamId          101759 non-null int64
# matchPeriod     101759 non-null object
# eventSec        101759 non-null float64
# subEventId      101759 non-null object
# id              101759 non-null int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 9.3+ MB

# %%
#104x76m pitch
xr = 1.04
yr = 0.76

fig=plt.figure()
#fig,ax = plt.subplots(figsize=(10.4,7.6))
ax=fig.add_subplot(1,1,1)
ax.axis('off')

plt.plot([0,104],[0,0],color="black")
plt.plot([0,0],[76,0],color="black")
plt.plot([0,104],[76,76],color="black")
plt.plot([104,104],[76,0],color="black")
plt.plot([52,52],[0,76],color="black")

plt.plot([104,86.32],[60,60],color="black")
plt.plot([86.32,104],[16,16],color="black")
plt.plot([86.32,86.32],[60,16],color="black")
plt.plot([104,97.97],[48,48],color="black")
plt.plot([104,97.97],[27.968,27.968],color="black")
plt.plot([97.97,97.97],[48,27.968],color="black")

plt.plot([0,17.68],[60,60],color='black')
plt.plot([0,17.68],[16,16],color='black')
plt.plot([17.68,17.68],[16,60],color='black')
plt.plot([0,6.03],[48,48],color='black')
plt.plot([0,6.03],[27.968,27.968],color='black')
plt.plot([6.03,6.03],[48,27.968],color='black')

plt.plot([104,104],[34,42],color="red")
plt.plot([0,0],[34,42],color='red')

penaltySpot = plt.Circle((92.04,38),0.25,color="black")
penaltySpotDF = plt.Circle((11,38),0.25,color='black')
centreSpot = plt.Circle((52,38),0.5,color="black")
centreCircle = plt.Circle((52,38),10,color="black",fill=False)

D = Arc((92.04,38),height=20,width=20,angle=0,theta1=125,theta2=235,color="black")
E = Arc((11.96,38),height=20,width=20,angle=0,theta1=305,theta2=55,color="black")

ax.add_patch(centreSpot)
ax.add_patch(centreCircle)
ax.add_patch(penaltySpot)
ax.add_patch(penaltySpotDF)
ax.add_patch(D)
ax.add_patch(E)

pitch = plt

pitch.show()

# %%
eventsWCTeam = eventsWC[eventsWC.teamId == IdUruguay]
eventsWCTeam
# Out:
#        eventId           subEventName  \
# 1589         8            Simple pass
# 1590         8              High pass
# 1592         8            Simple pass
# 1594         1  Ground defending duel
# 1596         8            Simple pass
# ...        ...                    ...
# 89940        1  Ground attacking duel
# 89941        8                  Cross
# 89943        8            Simple pass
# 89944        1  Ground attacking duel
# 89946        8                  Cross
#
#                                            tags  playerId  \
# 1589                             [{'id': 1801}]     21174
# 1590                             [{'id': 1802}]    227894
# 1592               [{'id': 1401}, {'id': 1802}]    116349
# 1594                [{'id': 703}, {'id': 1801}]    116349
# 1596                             [{'id': 1801}]      3433
# ...                                         ...       ...
# 89940  [{'id': 501}, {'id': 703}, {'id': 1801}]     70095
# 89941  [{'id': 401}, {'id': 801}, {'id': 1802}]     70095
# 89943                            [{'id': 1801}]     70379
# 89944  [{'id': 501}, {'id': 703}, {'id': 1801}]    116349
# 89946  [{'id': 402}, {'id': 801}, {'id': 1802}]    116349
#
#                                       positions  matchId eventName  teamId  \
# 1589   [{'y': 50, 'x': 47}, {'y': 73, 'x': 26}]  2057955      Pass   15670
# 1590   [{'y': 73, 'x': 26}, {'y': 95, 'x': 66}]  2057955      Pass   15670
# 1592   [{'y': 84, 'x': 59}, {'y': 95, 'x': 54}]  2057955      Pass   15670
# 1594   [{'y': 85, 'x': 47}, {'y': 39, 'x': 21}]  2057955      Duel   15670
# 1596   [{'y': 39, 'x': 21}, {'y': 79, 'x': 37}]  2057955      Pass   15670
# ...                                         ...      ...       ...     ...
# 89940  [{'y': 14, 'x': 71}, {'y': 17, 'x': 71}]  2058010      Duel   15670
# 89941  [{'y': 17, 'x': 71}, {'y': 68, 'x': 90}]  2058010      Pass   15670
# 89943  [{'y': 97, 'x': 75}, {'y': 94, 'x': 92}]  2058010      Pass   15670
# 89944  [{'y': 94, 'x': 92}, {'y': 95, 'x': 97}]  2058010      Duel   15670
# 89946    [{'y': 95, 'x': 97}, {'y': 0, 'x': 0}]  2058010      Pass   15670
#
#       matchPeriod     eventSec subEventId         id
# 1589           1H     3.406320         85  258688250
# 1590           1H     6.433663         83  258688252
# 1592           1H    11.489572         85  258688256
# 1594           1H    13.769340         12  258688258
# 1596           1H    20.694661         85  258688260
# ...           ...          ...        ...        ...
# 89940          2H  2966.917402         11  262103969
# 89941          2H  2969.048795         80  262103970
# 89943          2H  2975.192067         85  262103972
# 89944          2H  2977.768862         11  262103974
# 89946          2H  2979.019737         80  262103975
#
# [3855 rows x 12 columns]

# %%
eventsWCTeam.subEventName.unique()
# Out:
# array(['Simple pass', 'High pass', 'Ground defending duel', 'Touch',
#        'Smart pass', 'Throw in', 'Head pass', 'Ground attacking duel',
#        'Ground loose ball duel', 'Acceleration', 'Air duel', 'Clearance',
#        'Cross', 'Shot', 'Goal kick', 'Foul', 'Save attempt', 'Hand pass',
#        'Corner', 'Goalkeeper leaving line', 'Free Kick', 'Free kick shot',
#        'Launch', 'Free kick cross', '', 'Hand foul', 'Reflexes',
#        'Out of game foul'], dtype=object)

# %%
passesWCTeam = eventsWCTeam[eventsWCTeam.eventName == 'Pass']
passesWCTeam
# Out:
#        eventId subEventName                                      tags  \
# 1589         8  Simple pass                            [{'id': 1801}]
# 1590         8    High pass                            [{'id': 1802}]
# 1592         8  Simple pass              [{'id': 1401}, {'id': 1802}]
# 1596         8  Simple pass                            [{'id': 1801}]
# 1597         8  Simple pass                            [{'id': 1801}]
# ...        ...          ...                                       ...
# 89936        8    High pass                            [{'id': 1801}]
# 89939        8  Simple pass                            [{'id': 1801}]
# 89941        8        Cross  [{'id': 401}, {'id': 801}, {'id': 1802}]
# 89943        8  Simple pass                            [{'id': 1801}]
# 89946        8        Cross  [{'id': 402}, {'id': 801}, {'id': 1802}]
#
#        playerId                                 positions  matchId eventName  \
# 1589      21174  [{'y': 50, 'x': 47}, {'y': 73, 'x': 26}]  2057955      Pass
# 1590     227894  [{'y': 73, 'x': 26}, {'y': 95, 'x': 66}]  2057955      Pass
# 1592     116349  [{'y': 84, 'x': 59}, {'y': 95, 'x': 54}]  2057955      Pass
# 1596       3433  [{'y': 39, 'x': 21}, {'y': 79, 'x': 37}]  2057955      Pass
# 1597     116349  [{'y': 79, 'x': 37}, {'y': 40, 'x': 25}]  2057955      Pass
# ...         ...                                       ...      ...       ...
# 89936    116269  [{'y': 23, 'x': 38}, {'y': 37, 'x': 73}]  2058010      Pass
# 89939     70379  [{'y': 68, 'x': 70}, {'y': 14, 'x': 71}]  2058010      Pass
# 89941     70095  [{'y': 17, 'x': 71}, {'y': 68, 'x': 90}]  2058010      Pass
# 89943     70379  [{'y': 97, 'x': 75}, {'y': 94, 'x': 92}]  2058010      Pass
# 89946    116349    [{'y': 95, 'x': 97}, {'y': 0, 'x': 0}]  2058010      Pass
#
#        teamId matchPeriod     eventSec subEventId         id
# 1589    15670          1H     3.406320         85  258688250
# 1590    15670          1H     6.433663         83  258688252
# 1592    15670          1H    11.489572         85  258688256
# 1596    15670          1H    20.694661         85  258688260
# 1597    15670          1H    22.173712         85  258688262
# ...       ...         ...          ...        ...        ...
# 89936   15670          2H  2959.115772         83  262103961
# 89939   15670          2H  2963.345908         85  262103965
# 89941   15670          2H  2969.048795         80  262103970
# 89943   15670          2H  2975.192067         85  262103972
# 89946   15670          2H  2979.019737         80  262103975
#
# [2060 rows x 12 columns]

# %%
TeamPassesNames = passesWCTeam.join(playersNames.set_index('wyId'), on='playerId')
TeamPassesNames.head(30)
# Out:
#       eventId subEventName                          tags  playerId  \
# 1589        8  Simple pass                [{'id': 1801}]     21174
# 1590        8    High pass                [{'id': 1802}]    227894
# 1592        8  Simple pass  [{'id': 1401}, {'id': 1802}]    116349
# 1596        8  Simple pass                [{'id': 1801}]      3433
# 1597        8  Simple pass                [{'id': 1801}]    116349
# 1598        8  Simple pass                [{'id': 1801}]      3433
# 1599        8  Simple pass                [{'id': 1801}]    361807
# 1600        8  Simple pass                [{'id': 1801}]    213364
# 1601        8  Simple pass                [{'id': 1801}]      3433
# 1602        8  Simple pass                [{'id': 1801}]     20460
# 1603        8  Simple pass                [{'id': 1801}]      3433
# 1605        8   Smart pass                [{'id': 1802}]    227894
# 1608        8  Simple pass                [{'id': 1801}]    361807
# 1609        8  Simple pass                [{'id': 1801}]     20460
# 1610        8  Simple pass                [{'id': 1801}]    213364
# 1611        8  Simple pass                [{'id': 1801}]    227894
# 1612        8    High pass                [{'id': 1802}]      3433
# 1615        8    Head pass                [{'id': 1801}]    227894
# 1616        8    Head pass                [{'id': 1801}]    116349
# 1620        8  Simple pass                [{'id': 1801}]    361807
# 1621        8  Simple pass                [{'id': 1801}]    299618
# 1622        8  Simple pass                [{'id': 1801}]    116166
# 1623        8  Simple pass                [{'id': 1801}]    361807
# 1624        8  Simple pass                [{'id': 1801}]    213364
# 1625        8   Smart pass   [{'id': 901}, {'id': 1801}]      7972
# 1633        8    High pass                [{'id': 1802}]    227894
# 1649        8  Simple pass                [{'id': 1801}]    299618
# 1684        8    High pass                [{'id': 1801}]      7972
# 1690        8  Simple pass                [{'id': 1801}]    213364
# 1691        8  Simple pass                [{'id': 1801}]     21174
#
#                                      positions  matchId eventName  teamId  \
# 1589  [{'y': 50, 'x': 47}, {'y': 73, 'x': 26}]  2057955      Pass   15670
# 1590  [{'y': 73, 'x': 26}, {'y': 95, 'x': 66}]  2057955      Pass   15670
# 1592  [{'y': 84, 'x': 59}, {'y': 95, 'x': 54}]  2057955      Pass   15670
# 1596  [{'y': 39, 'x': 21}, {'y': 79, 'x': 37}]  2057955      Pass   15670
# 1597  [{'y': 79, 'x': 37}, {'y': 40, 'x': 25}]  2057955      Pass   15670
# 1598  [{'y': 40, 'x': 25}, {'y': 25, 'x': 25}]  2057955      Pass   15670
# 1599  [{'y': 25, 'x': 25}, {'y': 32, 'x': 42}]  2057955      Pass   15670
# 1600  [{'y': 32, 'x': 42}, {'y': 39, 'x': 22}]  2057955      Pass   15670
# 1601   [{'y': 39, 'x': 22}, {'y': 3, 'x': 35}]  2057955      Pass   15670
# 1602   [{'y': 3, 'x': 35}, {'y': 35, 'x': 27}]  2057955      Pass   15670
# 1603  [{'y': 35, 'x': 27}, {'y': 80, 'x': 32}]  2057955      Pass   15670
# 1605  [{'y': 88, 'x': 39}, {'y': 99, 'x': 57}]  2057955      Pass   15670
# 1608  [{'y': 55, 'x': 53}, {'y': 22, 'x': 42}]  2057955      Pass   15670
# 1609  [{'y': 22, 'x': 42}, {'y': 48, 'x': 49}]  2057955      Pass   15670
# 1610  [{'y': 48, 'x': 49}, {'y': 73, 'x': 38}]  2057955      Pass   15670
# 1611  [{'y': 73, 'x': 38}, {'y': 37, 'x': 40}]  2057955      Pass   15670
# 1612  [{'y': 37, 'x': 40}, {'y': 87, 'x': 80}]  2057955      Pass   15670
# 1615  [{'y': 82, 'x': 39}, {'y': 78, 'x': 65}]  2057955      Pass   15670
# 1616  [{'y': 78, 'x': 65}, {'y': 70, 'x': 59}]  2057955      Pass   15670
# 1620  [{'y': 75, 'x': 68}, {'y': 95, 'x': 80}]  2057955      Pass   15670
# 1621  [{'y': 95, 'x': 80}, {'y': 95, 'x': 56}]  2057955      Pass   15670
# 1622  [{'y': 95, 'x': 56}, {'y': 71, 'x': 69}]  2057955      Pass   15670
# 1623  [{'y': 71, 'x': 69}, {'y': 59, 'x': 67}]  2057955      Pass   15670
# 1624  [{'y': 59, 'x': 67}, {'y': 44, 'x': 72}]  2057955      Pass   15670
# 1625  [{'y': 44, 'x': 72}, {'y': 46, 'x': 76}]  2057955      Pass   15670
# 1633  [{'y': 55, 'x': 47}, {'y': 94, 'x': 67}]  2057955      Pass   15670
# 1649  [{'y': 82, 'x': 44}, {'y': 78, 'x': 50}]  2057955      Pass   15670
# 1684   [{'y': 96, 'x': 28}, {'y': 9, 'x': 26}]  2057955      Pass   15670
# 1690  [{'y': 19, 'x': 33}, {'y': 31, 'x': 46}]  2057955      Pass   15670
# 1691   [{'y': 31, 'x': 46}, {'y': 7, 'x': 54}]  2057955      Pass   15670
#
#      matchPeriod    eventSec subEventId         id         shortName
# 1589          1H    3.406320         85  258688250         E. Cavani
# 1590          1H    6.433663         83  258688252   J. Gim\u00e9nez
# 1592          1H   11.489572         85  258688256         M. Vecino
# 1596          1H   20.694661         85  258688260     D. God\u00edn
# 1597          1H   22.173712         85  258688262         M. Vecino
# 1598          1H   25.497872         85  258688263     D. God\u00edn
# 1599          1H   28.005935         85  258688264      R. Bentancur
# 1600          1H   30.400102         85  258688265  G. De Arrascaeta
# 1601          1H   32.591299         85  258688266     D. God\u00edn
# 1602          1H   36.916560         85  258688267   M. C\u00e1ceres
# 1603          1H   40.133749         85  258688268     D. God\u00edn
# 1605          1H   43.988159         86  258688270   J. Gim\u00e9nez
# 1608          1H   59.124420         85  258686151      R. Bentancur
# 1609          1H   61.117565         85  258686150   M. C\u00e1ceres
# 1610          1H   65.606925         85  258686152  G. De Arrascaeta
# 1611          1H   68.890401         85  258686153   J. Gim\u00e9nez
# 1612          1H   70.787062         83  258686154     D. God\u00edn
# 1615          1H   80.710810         82  258686156   J. Gim\u00e9nez
# 1616          1H   82.733878         82  258686157         M. Vecino
# 1620          1H   89.715597         85  258686160      R. Bentancur
# 1621          1H   91.261872         85  258686162    N. N\u00e1ndez
# 1622          1H   92.902229         85  258686164         G. Varela
# 1623          1H   96.394780         85  258686165      R. Bentancur
# 1624          1H   98.916903         85  258686167  G. De Arrascaeta
# 1625          1H  101.707638         86  258686170    L. Su\u00e1rez
# 1633          1H  113.440800         83  258686177   J. Gim\u00e9nez
# 1649          1H  166.789642         85  258686189    N. N\u00e1ndez
# 1684          1H  276.382938         83  258686227    L. Su\u00e1rez
# 1690          1H  303.393523         85  258686238  G. De Arrascaeta
# 1691          1H  304.493945         85  258686239         E. Cavani

# %%
passesWCTeamNames = passesWCTeam.join(playersNames.set_index('wyId'), on='playerId')
PlayerPasses = passesWCTeamNames[passesWCTeamNames.shortName.str.contains("L. Su")]
PlayerPasses
# Out:
#        eventId subEventName                         tags  playerId  \
# 1625         8   Smart pass  [{'id': 901}, {'id': 1801}]      7972
# 1684         8    High pass               [{'id': 1801}]      7972
# 1692         8    High pass               [{'id': 1802}]      7972
# 1730         8  Simple pass               [{'id': 1801}]      7972
# 1760         8  Simple pass               [{'id': 1801}]      7972
# ...        ...          ...                          ...       ...
# 89434        8    Head pass               [{'id': 1802}]      7972
# 89562        8    Head pass               [{'id': 1801}]      7972
# 89580        8  Simple pass               [{'id': 1802}]      7972
# 89832        8   Smart pass               [{'id': 1802}]      7972
# 89890        8  Simple pass               [{'id': 1801}]      7972
#
#                                       positions  matchId eventName  teamId  \
# 1625   [{'y': 44, 'x': 72}, {'y': 46, 'x': 76}]  2057955      Pass   15670
# 1684    [{'y': 96, 'x': 28}, {'y': 9, 'x': 26}]  2057955      Pass   15670
# 1692    [{'y': 7, 'x': 54}, {'y': 61, 'x': 89}]  2057955      Pass   15670
# 1730   [{'y': 71, 'x': 77}, {'y': 77, 'x': 59}]  2057955      Pass   15670
# 1760   [{'y': 44, 'x': 69}, {'y': 43, 'x': 77}]  2057955      Pass   15670
# ...                                         ...      ...       ...     ...
# 89434   [{'y': 22, 'x': 67}, {'y': 8, 'x': 74}]  2058010      Pass   15670
# 89562  [{'y': 16, 'x': 69}, {'y': 15, 'x': 71}]  2058010      Pass   15670
# 89580  [{'y': 84, 'x': 74}, {'y': 82, 'x': 76}]  2058010      Pass   15670
# 89832  [{'y': 14, 'x': 54}, {'y': 11, 'x': 98}]  2058010      Pass   15670
# 89890   [{'y': 6, 'x': 43}, {'y': 17, 'x': 58}]  2058010      Pass   15670
#
#       matchPeriod     eventSec subEventId         id       shortName
# 1625           1H   101.707638         86  258686170  L. Su\u00e1rez
# 1684           1H   276.382938         83  258686227  L. Su\u00e1rez
# 1692           1H   307.134185         83  258686241  L. Su\u00e1rez
# 1730           1H   392.429685         85  258686276  L. Su\u00e1rez
# 1760           1H   472.446166         85  258686323  L. Su\u00e1rez
# ...           ...          ...        ...        ...             ...
# 89434          2H  1129.126193         82  262103361  L. Su\u00e1rez
# 89562          2H  1681.650842         82  262103541  L. Su\u00e1rez
# 89580          2H  1718.952038         85  262103575  L. Su\u00e1rez
# 89832          2H  2482.764826         86  262103782  L. Su\u00e1rez
# 89890          2H  2801.482677         85  262103904  L. Su\u00e1rez
#
# [128 rows x 13 columns]

# %%
pp = PlayerPasses.groupby('subEventName').subEventName.count()
pp.plot.barh(rot=0, color='c', label='Tipos de pase del jugador')
plt.legend()

# %%
fig=plt.figure()
#fig,ax = plt.subplots(figsize=(10.4,7.6))
ax=fig.add_subplot(1,1,1)
ax.axis('off')

plt.plot([0,104],[0,0],color="black")
plt.plot([0,0],[76,0],color="black")
plt.plot([0,104],[76,76],color="black")
plt.plot([104,104],[76,0],color="black")
plt.plot([52,52],[0,76],color="black")

plt.plot([104,86.32],[60,60],color="black")
plt.plot([86.32,104],[16,16],color="black")
plt.plot([86.32,86.32],[60,16],color="black")
plt.plot([104,97.97],[48,48],color="black")
plt.plot([104,97.97],[27.968,27.968],color="black")
plt.plot([97.97,97.97],[48,27.968],color="black")

plt.plot([0,17.68],[60,60],color='black')
plt.plot([0,17.68],[16,16],color='black')
plt.plot([17.68,17.68],[16,60],color='black')
plt.plot([0,6.03],[48,48],color='black')
plt.plot([0,6.03],[27.968,27.968],color='black')
plt.plot([6.03,6.03],[48,27.968],color='black')

plt.plot([104,104],[34,42],color="red")
plt.plot([0,0],[34,42],color='red')

penaltySpot = plt.Circle((92.04,38),0.25,color="black")
penaltySpotDF = plt.Circle((11,38),0.25,color='black')
centreSpot = plt.Circle((52,38),0.5,color="black")
centreCircle = plt.Circle((52,38),10,color="black",fill=False)

D = Arc((92.04,38),height=20,width=20,angle=0,theta1=125,theta2=235,color="black")
E = Arc((11.96,38),height=20,width=20,angle=0,theta1=305,theta2=55,color="black")

ax.add_patch(centreSpot)
ax.add_patch(centreCircle)
ax.add_patch(penaltySpot)
ax.add_patch(penaltySpotDF)
ax.add_patch(D)
ax.add_patch(E)

PlayerPassPositions = PlayerPasses.positions
p1 = []
p2 = []
x1 = []
x2 = []
y1 = []
y2 = []
for i in PlayerPassPositions.values:
    p1.append(i[0])
    p2.append(i[1])
for p in p1:
    x1.append(p['x']*xr)
    y1.append(p['y']*yr)
for p in p2:
    x2.append(p['x']*xr)
    y2.append(p['y']*yr)
    
plt.plot([x1,x2],[y1,y2],color='c',linewidth=1, linestyle='dashed', marker='.', markevery=[0])
plt.show()

# %%
fig=plt.figure()
#fig,ax = plt.subplots(figsize=(10.4,7.6))
ax=fig.add_subplot(1,1,1)
ax.axis('off')

plt.plot([0,104],[0,0],color="black")
plt.plot([0,0],[76,0],color="black")
plt.plot([0,104],[76,76],color="black")
plt.plot([104,104],[76,0],color="black")
plt.plot([52,52],[0,76],color="black")

plt.plot([104,86.32],[60,60],color="black")
plt.plot([86.32,104],[16,16],color="black")
plt.plot([86.32,86.32],[60,16],color="black")
plt.plot([104,97.97],[48,48],color="black")
plt.plot([104,97.97],[27.968,27.968],color="black")
plt.plot([97.97,97.97],[48,27.968],color="black")

plt.plot([0,17.68],[60,60],color='black')
plt.plot([0,17.68],[16,16],color='black')
plt.plot([17.68,17.68],[16,60],color='black')
plt.plot([0,6.03],[48,48],color='black')
plt.plot([0,6.03],[27.968,27.968],color='black')
plt.plot([6.03,6.03],[48,27.968],color='black')

plt.plot([104,104],[34,42],color="red")
plt.plot([0,0],[34,42],color='red')

penaltySpot = plt.Circle((92.04,38),0.25,color="black")
penaltySpotDF = plt.Circle((11,38),0.25,color='black')
centreSpot = plt.Circle((52,38),0.5,color="black")
centreCircle = plt.Circle((52,38),10,color="black",fill=False)

D = Arc((92.04,38),height=20,width=20,angle=0,theta1=125,theta2=235,color="black")
E = Arc((11.96,38),height=20,width=20,angle=0,theta1=305,theta2=55,color="black")

ax.add_patch(centreSpot)
ax.add_patch(centreCircle)
ax.add_patch(penaltySpot)
ax.add_patch(penaltySpotDF)
ax.add_patch(D)
ax.add_patch(E)

ir = IsotonicRegression()
y3 = ir.fit_transform(x1, y1)

plt.plot(x1, y1, 'r.', markersize=12)
plt.plot(x1, y3, 'g.', markersize=12)
plt.show()

#Dónde empiezan sus pases

# %%
fig=plt.figure()
#fig,ax = plt.subplots(figsize=(10.4,7.6))
ax=fig.add_subplot(1,1,1)
ax.axis('off')

plt.plot([0,104],[0,0],color="black")
plt.plot([0,0],[76,0],color="black")
plt.plot([0,104],[76,76],color="black")
plt.plot([104,104],[76,0],color="black")
plt.plot([52,52],[0,76],color="black")

plt.plot([104,86.32],[60,60],color="black")
plt.plot([86.32,104],[16,16],color="black")
plt.plot([86.32,86.32],[60,16],color="black")
plt.plot([104,97.97],[48,48],color="black")
plt.plot([104,97.97],[27.968,27.968],color="black")
plt.plot([97.97,97.97],[48,27.968],color="black")

plt.plot([0,17.68],[60,60],color='black')
plt.plot([0,17.68],[16,16],color='black')
plt.plot([17.68,17.68],[16,60],color='black')
plt.plot([0,6.03],[48,48],color='black')
plt.plot([0,6.03],[27.968,27.968],color='black')
plt.plot([6.03,6.03],[48,27.968],color='black')

plt.plot([104,104],[34,42],color="red")
plt.plot([0,0],[34,42],color='red')

penaltySpot = plt.Circle((92.04,38),0.25,color="black")
penaltySpotDF = plt.Circle((11,38),0.25,color='black')
centreSpot = plt.Circle((52,38),0.5,color="black")
centreCircle = plt.Circle((52,38),10,color="black",fill=False)

D = Arc((92.04,38),height=20,width=20,angle=0,theta1=125,theta2=235,color="black")
E = Arc((11.96,38),height=20,width=20,angle=0,theta1=305,theta2=55,color="black")

ax.add_patch(centreSpot)
ax.add_patch(centreCircle)
ax.add_patch(penaltySpot)
ax.add_patch(penaltySpotDF)
ax.add_patch(D)
ax.add_patch(E)

ir = IsotonicRegression()
y4 = ir.fit_transform(x2, y2)

plt.plot(x2, y2, 'm.', markersize=12)
plt.plot(x2, y4, 'b.', markersize=12)
plt.show()

#Dónde terminan sus pases

# %%
fig=plt.figure()
#fig,ax = plt.subplots(figsize=(10.4,7.6))
ax=fig.add_subplot(1,1,1)
ax.axis('off')

plt.plot([0,104],[0,0],color="black")
plt.plot([0,0],[76,0],color="black")
plt.plot([0,104],[76,76],color="black")
plt.plot([104,104],[76,0],color="black")
plt.plot([52,52],[0,76],color="black")

plt.plot([104,86.32],[60,60],color="black")
plt.plot([86.32,104],[16,16],color="black")
plt.plot([86.32,86.32],[60,16],color="black")
plt.plot([104,97.97],[48,48],color="black")
plt.plot([104,97.97],[27.968,27.968],color="black")
plt.plot([97.97,97.97],[48,27.968],color="black")

plt.plot([0,17.68],[60,60],color='black')
plt.plot([0,17.68],[16,16],color='black')
plt.plot([17.68,17.68],[16,60],color='black')
plt.plot([0,6.03],[48,48],color='black')
plt.plot([0,6.03],[27.968,27.968],color='black')
plt.plot([6.03,6.03],[48,27.968],color='black')

plt.plot([104,104],[34,42],color="red")
plt.plot([0,0],[34,42],color='red')

penaltySpot = plt.Circle((92.04,38),0.25,color="black")
penaltySpotDF = plt.Circle((11,38),0.25,color='black')
centreSpot = plt.Circle((52,38),0.5,color="black")
centreCircle = plt.Circle((52,38),10,color="black",fill=False)

D = Arc((92.04,38),height=20,width=20,angle=0,theta1=125,theta2=235,color="black")
E = Arc((11.96,38),height=20,width=20,angle=0,theta1=305,theta2=55,color="black")

ax.add_patch(centreSpot)
ax.add_patch(centreCircle)
ax.add_patch(penaltySpot)
ax.add_patch(penaltySpotDF)
ax.add_patch(D)
ax.add_patch(E)

plt.plot([x1,x1],[y3,y4],color='c', marker=10, markevery=[1])
plt.show()

#Arreglar este esquema de pases típicos horizontales

# %%
PassClusters = pd.DataFrame(np.transpose(np.array([x1,y1,x2,y2,PlayerPasses.subEventName])),columns=['x1','y1','x2','y2','type'])
PassClusters

ct = pd.crosstab(PassClusters['type'], PassClusters['y1'])
print(ct)
# Out:
# y1           2.28   3.04   4.56   5.32   7.60   9.12   9.88   10.64  11.40  \
# type
# Cross            0      0      0      0      1      0      0      0      0
# Head pass        0      0      0      0      1      0      0      0      0
# High pass        0      0      0      1      0      0      0      0      0
# Simple pass      1      1      2      0      1      1      1      0      2
# Smart pass       0      0      0      0      0      0      0      1      0
#
# y1           12.16  ...  65.36  66.88  67.64  69.16  69.92  70.68  72.96  \
# type                ...
# Cross            0  ...      0      0      1      0      1      1      0
# Head pass        1  ...      0      0      1      0      0      1      0
# High pass        0  ...      0      0      0      0      0      0      1
# Simple pass      3  ...      1      1      2      2      1      0      5
# Smart pass       0  ...      0      0      0      0      0      0      0
#
# y1           73.72  74.48  75.24
# type
# Cross            0      0      0
# Head pass        1      0      0
# High pass        0      0      0
# Simple pass      0      1      1
# Smart pass       0      0      0
#
# [5 rows x 67 columns]

# %%
PassClusters = pd.DataFrame(np.transpose(np.array([x1,y1,x2,y2])),columns=['x1','y1','x2','y2'])

# %%
y_inertia = []
for i in range(80):
    model = KMeans(n_clusters=i+1)
    model.fit(PassClusters)
    y_inertia.append(model.inertia_)
    
plt.plot([x for x in range(len(y_inertia))],y_inertia,color='r')
plt.show()

# %%
#t-distributed stochastic neighbor embedding
model = TSNE(learning_rate=100)
transformed = model.fit_transform(PassClusters)
xs = transformed[:,0]
ys = transformed[:,1]
plt.scatter(xs,ys,c=x1)
plt.show()

# %%
pca = PCA(n_components=2)
pca.fit(PassClusters)
transformed = pca.transform(PassClusters)
xs = transformed[:,0]
ys = transformed[:,1]
plt.scatter(xs,ys,c=x1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
clusters = 5

model = KMeans(n_clusters=clusters)
model.fit(PassClusters)
labels = model.predict(PassClusters)

PassClusters['colors'] = labels

fig=plt.figure()
#fig,ax = plt.subplots(figsize=(10.4,7.6))
ax=fig.add_subplot(1,1,1)
ax.axis('off')

plt.plot([0,104],[0,0],color="black")
plt.plot([0,0],[76,0],color="black")
plt.plot([0,104],[76,76],color="black")
plt.plot([104,104],[76,0],color="black")
plt.plot([52,52],[0,76],color="black")

plt.plot([104,86.32],[60,60],color="black")
plt.plot([86.32,104],[16,16],color="black")
plt.plot([86.32,86.32],[60,16],color="black")
plt.plot([104,97.97],[48,48],color="black")
plt.plot([104,97.97],[27.968,27.968],color="black")
plt.plot([97.97,97.97],[48,27.968],color="black")

plt.plot([0,17.68],[60,60],color='black')
plt.plot([0,17.68],[16,16],color='black')
plt.plot([17.68,17.68],[16,60],color='black')
plt.plot([0,6.03],[48,48],color='black')
plt.plot([0,6.03],[27.968,27.968],color='black')
plt.plot([6.03,6.03],[48,27.968],color='black')

plt.plot([104,104],[34,42],color="red")
plt.plot([0,0],[34,42],color='red')

penaltySpot = plt.Circle((92.04,38),0.25,color="black")
penaltySpotDF = plt.Circle((11,38),0.25,color='black')
centreSpot = plt.Circle((52,38),0.5,color="black")
centreCircle = plt.Circle((52,38),10,color="black",fill=False)

D = Arc((92.04,38),height=20,width=20,angle=0,theta1=125,theta2=235,color="black")
E = Arc((11.96,38),height=20,width=20,angle=0,theta1=305,theta2=55,color="black")

ax.add_patch(centreSpot)
ax.add_patch(centreCircle)
ax.add_patch(penaltySpot)
ax.add_patch(penaltySpotDF)
ax.add_patch(D)
ax.add_patch(E)

plt.plot([x1,x2],[y1,y2],c='silver',linewidth=1, linestyle='dashed')
plt.scatter(x1,y1,c=PassClusters.colors,cmap='hsv')

plt.show()

# %%
TeamShots = eventsWCTeam[eventsWCTeam.eventName == 'Shot']
TeamShots
# Out:
#        eventId subEventName  \
# 1762        10         Shot
# 1860        10         Shot
# 2005        10         Shot
# 2011        10         Shot
# 2124        10         Shot
# 2477        10         Shot
# 2870        10         Shot
# 2912        10         Shot
# 3144        10         Shot
# 3225        10         Shot
# 3241        10         Shot
# 4982        10         Shot
# 5145        10         Shot
# 5285        10         Shot
# 5310        10         Shot
# 5337        10         Shot
# 6074        10         Shot
# 6103        10         Shot
# 6143        10         Shot
# 6279        10         Shot
# 6306        10         Shot
# 6307        10         Shot
# 6431        10         Shot
# 6498        10         Shot
# 6612        10         Shot
# 6890        10         Shot
# 6961        10         Shot
# 7515        10         Shot
# 7671        10         Shot
# 7684        10         Shot
# 7856        10         Shot
# 7901        10         Shot
# 7945        10         Shot
# 7951        10         Shot
# 7953        10         Shot
# 8004        10         Shot
# 74604       10         Shot
# 74697       10         Shot
# 74859       10         Shot
# 75180       10         Shot
# 75244       10         Shot
# 75530       10         Shot
# 88888       10         Shot
# 88957       10         Shot
# 89048       10         Shot
# 89075       10         Shot
# 89077       10         Shot
# 89328       10         Shot
# 89382       10         Shot
# 89429       10         Shot
# 89431       10         Shot
#
#                                                     tags  playerId  \
# 1762   [{'id': 402}, {'id': 201}, {'id': 1205}, {'id'...     21174
# 1860   [{'id': 402}, {'id': 201}, {'id': 1213}, {'id'...      7972
# 2005   [{'id': 401}, {'id': 2101}, {'id': 201}, {'id'...     21174
# 2011   [{'id': 402}, {'id': 201}, {'id': 1212}, {'id'...      7972
# 2124   [{'id': 402}, {'id': 201}, {'id': 1212}, {'id'...    116349
# 2477   [{'id': 402}, {'id': 201}, {'id': 1203}, {'id'...      7972
# 2870           [{'id': 402}, {'id': 2101}, {'id': 1802}]     86340
# 2912   [{'id': 401}, {'id': 2101}, {'id': 201}, {'id'...     21174
# 3144   [{'id': 402}, {'id': 201}, {'id': 1203}, {'id'...     21174
# 3225   [{'id': 402}, {'id': 2101}, {'id': 201}, {'id'...     20460
# 3241   [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...    227894
# 4982           [{'id': 401}, {'id': 2101}, {'id': 1802}]      7972
# 5145   [{'id': 401}, {'id': 201}, {'id': 1215}, {'id'...     21174
# 5285   [{'id': 402}, {'id': 201}, {'id': 1204}, {'id'...     86340
# 5310   [{'id': 101}, {'id': 401}, {'id': 201}, {'id':...      7972
# 5337   [{'id': 1901}, {'id': 402}, {'id': 2101}, {'id...     21174
# 6074   [{'id': 1901}, {'id': 403}, {'id': 201}, {'id'...     86340
# 6103           [{'id': 401}, {'id': 2101}, {'id': 1802}]      7972
# 6143   [{'id': 403}, {'id': 201}, {'id': 1216}, {'id'...     20460
# 6279   [{'id': 402}, {'id': 2101}, {'id': 201}, {'id'...     20460
# 6306           [{'id': 402}, {'id': 2101}, {'id': 1802}]    333571
# 6307   [{'id': 403}, {'id': 1401}, {'id': 201}, {'id'...     21174
# 6431   [{'id': 402}, {'id': 201}, {'id': 1201}, {'id'...     21174
# 6498           [{'id': 402}, {'id': 1210}, {'id': 1802}]      7972
# 6612   [{'id': 402}, {'id': 201}, {'id': 1212}, {'id'...    116349
# 6890   [{'id': 401}, {'id': 2101}, {'id': 201}, {'id'...    116269
# 6961   [{'id': 1901}, {'id': 402}, {'id': 201}, {'id'...    361807
# 7515           [{'id': 401}, {'id': 2101}, {'id': 1802}]    361807
# 7671           [{'id': 402}, {'id': 1210}, {'id': 1802}]      3433
# 7684   [{'id': 402}, {'id': 201}, {'id': 1210}, {'id'...     21174
# 7856   [{'id': 401}, {'id': 201}, {'id': 1207}, {'id'...     70095
# 7901   [{'id': 401}, {'id': 2101}, {'id': 201}, {'id'...     21174
# 7945   [{'id': 401}, {'id': 201}, {'id': 1209}, {'id'...     70095
# 7951   [{'id': 403}, {'id': 201}, {'id': 1204}, {'id'...      3433
# 7953   [{'id': 101}, {'id': 401}, {'id': 201}, {'id':...     21174
# 8004           [{'id': 402}, {'id': 2101}, {'id': 1802}]    333571
# 74604  [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...     21174
# 74697          [{'id': 402}, {'id': 2101}, {'id': 1802}]      7972
# 74859          [{'id': 402}, {'id': 1216}, {'id': 1802}]      7972
# 75180          [{'id': 402}, {'id': 1214}, {'id': 1802}]    299618
# 75244  [{'id': 402}, {'id': 201}, {'id': 1211}, {'id'...     21174
# 75530  [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...     21174
# 88888          [{'id': 402}, {'id': 1216}, {'id': 1802}]     20460
# 88957  [{'id': 402}, {'id': 201}, {'id': 1202}, {'id'...    116349
# 89048  [{'id': 401}, {'id': 201}, {'id': 1203}, {'id'...    299618
# 89075  [{'id': 403}, {'id': 201}, {'id': 1204}, {'id'...     20460
# 89077  [{'id': 401}, {'id': 201}, {'id': 1215}, {'id'...      3433
# 89328  [{'id': 401}, {'id': 201}, {'id': 1212}, {'id'...    361807
# 89382          [{'id': 402}, {'id': 1215}, {'id': 1802}]     20460
# 89429          [{'id': 401}, {'id': 2101}, {'id': 1802}]     70095
# 89431  [{'id': 401}, {'id': 201}, {'id': 1212}, {'id'...     70095
#
#                                         positions  matchId eventName  teamId  \
# 1762   [{'y': 50, 'x': 77}, {'y': 100, 'x': 100}]  2057955      Shot   15670
# 1860   [{'y': 70, 'x': 90}, {'y': 100, 'x': 100}]  2057955      Shot   15670
# 2005   [{'y': 32, 'x': 82}, {'y': 100, 'x': 100}]  2057955      Shot   15670
# 2011   [{'y': 41, 'x': 93}, {'y': 100, 'x': 100}]  2057955      Shot   15670
# 2124   [{'y': 79, 'x': 71}, {'y': 100, 'x': 100}]  2057955      Shot   15670
# 2477   [{'y': 61, 'x': 93}, {'y': 100, 'x': 100}]  2057955      Shot   15670
# 2870   [{'y': 66, 'x': 73}, {'y': 100, 'x': 100}]  2057955      Shot   15670
# 2912   [{'y': 58, 'x': 89}, {'y': 100, 'x': 100}]  2057955      Shot   15670
# 3144   [{'y': 43, 'x': 81}, {'y': 100, 'x': 100}]  2057955      Shot   15670
# 3225   [{'y': 51, 'x': 88}, {'y': 100, 'x': 100}]  2057955      Shot   15670
# 3241   [{'y': 47, 'x': 90}, {'y': 100, 'x': 100}]  2057955      Shot   15670
# 4982       [{'y': 32, 'x': 81}, {'y': 0, 'x': 0}]  2057957      Shot   15670
# 5145       [{'y': 37, 'x': 91}, {'y': 0, 'x': 0}]  2057957      Shot   15670
# 5285       [{'y': 23, 'x': 96}, {'y': 0, 'x': 0}]  2057957      Shot   15670
# 5310       [{'y': 54, 'x': 94}, {'y': 0, 'x': 0}]  2057957      Shot   15670
# 5337       [{'y': 69, 'x': 91}, {'y': 0, 'x': 0}]  2057957      Shot   15670
# 6074       [{'y': 63, 'x': 93}, {'y': 0, 'x': 0}]  2057957      Shot   15670
# 6103       [{'y': 75, 'x': 87}, {'y': 0, 'x': 0}]  2057957      Shot   15670
# 6143       [{'y': 57, 'x': 93}, {'y': 0, 'x': 0}]  2057957      Shot   15670
# 6279       [{'y': 40, 'x': 90}, {'y': 0, 'x': 0}]  2057957      Shot   15670
# 6306       [{'y': 44, 'x': 75}, {'y': 0, 'x': 0}]  2057957      Shot   15670
# 6307       [{'y': 59, 'x': 89}, {'y': 0, 'x': 0}]  2057957      Shot   15670
# 6431       [{'y': 48, 'x': 87}, {'y': 0, 'x': 0}]  2057957      Shot   15670
# 6498       [{'y': 51, 'x': 84}, {'y': 0, 'x': 0}]  2057957      Shot   15670
# 6612       [{'y': 42, 'x': 71}, {'y': 0, 'x': 0}]  2057958      Shot   15670
# 6890       [{'y': 26, 'x': 78}, {'y': 0, 'x': 0}]  2057958      Shot   15670
# 6961       [{'y': 56, 'x': 91}, {'y': 0, 'x': 0}]  2057958      Shot   15670
# 7515       [{'y': 75, 'x': 92}, {'y': 0, 'x': 0}]  2057958      Shot   15670
# 7671       [{'y': 38, 'x': 47}, {'y': 0, 'x': 0}]  2057958      Shot   15670
# 7684       [{'y': 42, 'x': 87}, {'y': 0, 'x': 0}]  2057958      Shot   15670
# 7856       [{'y': 30, 'x': 75}, {'y': 0, 'x': 0}]  2057958      Shot   15670
# 7901       [{'y': 59, 'x': 89}, {'y': 0, 'x': 0}]  2057958      Shot   15670
# 7945       [{'y': 28, 'x': 82}, {'y': 0, 'x': 0}]  2057958      Shot   15670
# 7951       [{'y': 50, 'x': 95}, {'y': 0, 'x': 0}]  2057958      Shot   15670
# 7953       [{'y': 49, 'x': 99}, {'y': 0, 'x': 0}]  2057958      Shot   15670
# 8004       [{'y': 34, 'x': 74}, {'y': 0, 'x': 0}]  2057958      Shot   15670
# 74604      [{'y': 55, 'x': 96}, {'y': 0, 'x': 0}]  2058002      Shot   15670
# 74697      [{'y': 70, 'x': 90}, {'y': 0, 'x': 0}]  2058002      Shot   15670
# 74859      [{'y': 79, 'x': 83}, {'y': 0, 'x': 0}]  2058002      Shot   15670
# 75180      [{'y': 96, 'x': 73}, {'y': 0, 'x': 0}]  2058002      Shot   15670
# 75244      [{'y': 29, 'x': 91}, {'y': 0, 'x': 0}]  2058002      Shot   15670
# 75530      [{'y': 34, 'x': 87}, {'y': 0, 'x': 0}]  2058002      Shot   15670
# 88888      [{'y': 89, 'x': 48}, {'y': 0, 'x': 0}]  2058010      Shot   15670
# 88957      [{'y': 64, 'x': 87}, {'y': 0, 'x': 0}]  2058010      Shot   15670
# 89048      [{'y': 35, 'x': 73}, {'y': 0, 'x': 0}]  2058010      Shot   15670
# 89075      [{'y': 50, 'x': 90}, {'y': 0, 'x': 0}]  2058010      Shot   15670
# 89077      [{'y': 43, 'x': 98}, {'y': 0, 'x': 0}]  2058010      Shot   15670
# 89328      [{'y': 72, 'x': 82}, {'y': 0, 'x': 0}]  2058010      Shot   15670
# 89382      [{'y': 75, 'x': 87}, {'y': 0, 'x': 0}]  2058010      Shot   15670
# 89429      [{'y': 41, 'x': 78}, {'y': 0, 'x': 0}]  2058010      Shot   15670
# 89431      [{'y': 44, 'x': 82}, {'y': 0, 'x': 0}]  2058010      Shot   15670
#
#       matchPeriod     eventSec subEventId         id
# 1762           1H   476.278045        100  258686325
# 1860           1H   796.334052        100  258686422
# 2005           1H  1348.670311        100  258686600
# 2011           1H  1384.479894        100  258686608
# 2124           1H  1725.947523        100  258686748
# 2477           2H    50.713174        100  258687231
# 2870           2H  1349.507918        100  258687714
# 2912           2H  1474.298300        100  258687765
# 3144           2H  2249.384976        100  258688043
# 3225           2H  2567.468830        100  258688131
# 3241           2H  2640.212250        100  258688146
# 4982           1H   113.214017        100  259526930
# 5145           1H   730.608594        100  259527118
# 5285           1H  1204.071576        100  259527307
# 5310           1H  1334.753085        100  259528907
# 5337           1H  1470.360312        100  259527372
# 6074           2H   991.308608        100  259528216
# 6103           2H  1086.433277        100  259528258
# 6143           2H  1375.027834        100  259528326
# 6279           2H  1912.914006        100  259528489
# 6306           2H  2055.568612        100  259528533
# 6307           2H  2057.130286        100  259528537
# 6431           2H  2416.952373        100  259528644
# 6498           2H  2598.404181        100  259528744
# 6612           1H    64.743361        100  260303763
# 6890           1H  1360.903367        100  260304111
# 6961           1H  1666.255003        100  260304197
# 7515           2H   800.481387        100  260304871
# 7671           2H  1372.180376        100  260305063
# 7684           2H  1414.379860        100  260305080
# 7856           2H  2215.733033        100  260305297
# 7901           2H  2426.505505        100  260305348
# 7945           2H  2659.844611        100  260305412
# 7951           2H  2689.085007        100  260305415
# 7953           2H  2691.130049        100  260305416
# 8004           2H  2969.831277        100  260305516
# 74604          1H   403.340461        100  261094396
# 74697          1H   807.714767        100  261094508
# 74859          1H  1308.304512        100  261094726
# 75180          1H  2490.962663        100  261095140
# 75244          1H  2806.311348        100  261095190
# 75530          2H   970.929691        100  261095586
# 88888          1H  1817.115502        100  262102716
# 88957          1H  2100.692744        100  262102786
# 89048          1H  2502.753349        100  262102888
# 89075          1H  2587.372791        100  262102916
# 89077          1H  2588.858162        100  262102919
# 89328          2H   609.867748        100  262103243
# 89382          2H   783.360503        100  262103289
# 89429          2H  1095.366259        100  262103355
# 89431          2H  1098.245776        100  262103356

# %%
TeamShotsNames = TeamShots.join(playersNames.set_index('wyId'), on='playerId')

TeamShotsPositions = TeamShotsNames.positions
p1 = []
p2 = []
x1 = []
x2 = []
y1 = []
y2 = []
for i in TeamShotsPositions.values:
    p1.append(i[0])
    p2.append(i[1])
for p in p1:
    x1.append(p['x'])
    y1.append(p['y'])
for p in p2:
    x2.append(p['x'])
    y2.append(p['y']) 
    
plt.plot([x1,x2],[y1,y2],color='c',linewidth=1, linestyle='dashed', marker='.', markevery=[0])
plt.show()

tsn = TeamShotsNames.groupby('shortName').shortName.count()
tsn.plot.barh(rot=0, color='c', label='Tiros por jugador en mundial')
plt.legend()
